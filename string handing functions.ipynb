# %% [markdown]
# # TASK 1

# %% [markdown]
# ### EXAMPLE FOR STRING HANDLING FUNCTIONS

# %% [markdown]
# ## upper()

# %% [markdown]
# ##### example 1

# %%
string1=input("enter any string that will be changed into uppercase :")
print(string1.upper())
# Out:
# enter any string that will be changed into uppercase : raja
# RAJA

# %% [markdown]
# ##### example 2

# %%
string1=input("NAME :")
string2=input("city :")
print("Hi {0} your are from {1}".format(string1.upper(),string2.upper()))
# Out:
# NAME : raja
# city : mannai
# Hi RAJA your are from MANNAI

# %% [markdown]
# ## lower()

# %% [markdown]
# ##### example 1

# %%
username="karan001"
passward="karan@123"
checkuser=input("enter user name").lower()
checkpassward=input("eneter your passwar").lower()
if username==checkuser and passward==checkpassward :
    print("welcome admin youre logined successfully")
# Out:
# enter user name KARAN001
# eneter your passwar KARAN@123
# welcome admin youre logined successfully

# %% [markdown]
# ##### example 2

# %%
string1=input("enter any string that will be changed into lowercase :")
print(string1.lower())
# Out:
# enter any string that will be changed into lowercase : ram is a goodBoy
# ram is a goodboy

# %% [markdown]
# ## title()

# %% [markdown]
# ##### example 1

# %%
tittle=input("enter a your title:")
print(tittle.title())
# Out:
# enter a your title: this is my project
# This Is My Project

# %% [markdown]
# ##### example 2

# %%
tittle=input("enter a your title:")
discription=input("eneter your project description")
print("projecvt tittle :",tittle.title())
print("description".title())
print(discription)
# Out:
# enter a your title: thuwhgieufg
# eneter your project description sfuhvwudofhy7gijkvn wiuuhvuwfh iuhjvwivhnwijf nidfnhifjnqoifqjoqjod ifhwquibnwiufjnwfinw safhnwiufhi
# projecvt tittle : Thuwhgieufg
# Description
# sfuhvwudofhy7gijkvn wiuuhvuwfh iuhjvwivhnwijf nidfnhifjnqoifqjoqjod ifhwquibnwiufjnwfinw safhnwiufhi

# %% [markdown]
# ## capitalize()

# %% [markdown]
# ##### example 1

# %%
str1=input("enter a string you need to capitalaize the first letter:")
print(str1.capitalize())
# Out:
# enter a string you need to capitalaize the first letter: rakesh
# Rakesh

# %% [markdown]
# ##### example 2

# %%
name=input("enter your name :")

print("hellow {} welcome to python programming".format(str1.capitalize()))
# Out:
# enter your name : rakesh
# hellow Rakesh welcome to python programming

# %% [markdown]
# ## strip()

# %% [markdown]
# ##### example 1

# %%
string1=" wel"
string2="come "
print("length of string1 is ",len(string1))
print("length of string2 is ",len(string2))
string3=string1.strip()+string2.strip()
print("length of string 3 that strip and join string1 and string2",len(string3))
# Out:
# length of string1 is  4
# length of string2 is  5
# length of string 3 that strip and join string1 and string2 7

# %% [markdown]
# ##### example 2

# %%
username=input("enter username whitespace not taken by the system")
print("welcome",username.strip())
# Out:
# enter username whitespace not taken by the system    rajasekar
# welcome rajasekar

# %% [markdown]
# ## lstrip()

# %% [markdown]
# ##### example 1

# %%
firstname="raja"
secondname=" sekar"
print("concadination without using lstrip :",firstname+secondname)
print("concadination after   using lstrip :",firstname+secondname.lstrip())
# Out:
# concadination without using lstrip : raja sekar
# concadination after   using lstrip : rajasekar

# %% [markdown]
# ##### example 2

# %%
countrycode=(input("eneter country code :eg(india:91+)"))
phonenumber=(input("eneter your phone numeber :"))
fullnumber="+"+countrycode.lstrip()+phonenumber.lstrip()
print("your phone number saved as",fullnumber)
# Out:
# eneter country code :eg(india:91+) 98
# eneter your phone numeber : 9965314383
# your phone number saved as +989965314383

# %% [markdown]
# ## rstrip()

# %% [markdown]
# ##### example 1

# %%
firstname="rajaa"
secondname=" sekar"
print("concadination without using rstrip :",firstname.rstrip("a")+secondname)
print("concadination after   using rstrip :",firstname+secondname)
# Out:
# concadination without using rstrip : raj sekar
# concadination after   using rstrip : rajaa sekar

# %% [markdown]
# ##### example 2

# %%
string1="welcome to python   "
string2=string1.rstrip()
print(string2)
string1="welcome to python"
print(string1.rstrip("n"))
# Out:
# welcome to python
# welcome to pytho

# %% [markdown]
# ## replace()

# %% [markdown]
# ##### example 1

# %%
string1="hellow sir"
string2=string1.replace("hellow","welcome")
print(string1)
print(string2)
# Out:
# hellow sir
# welcome sir

# %% [markdown]
# ##### example 2

# %%
applestring="""Apple is a fruit.
An Apple a day keeps the doctor away.
I love Apple products."""
orengestring=applestring.replace("Apple","orenge")
print("apple :",applestring)
print("orenge :",orengestring)
# Out:
# apple : Apple is a fruit.
# An Apple a day keeps the doctor away.
# I love Apple products.
# orenge : orenge is a fruit.
# An orenge a day keeps the doctor away.
# I love orenge products.

# %% [markdown]
# ## find()

# %% [markdown]
# ##### example 1

# %%
string1="The matrix is everywhere"
print("string1 :",string1)
print("posiiton of matrix in string 1",string1.find("matrix"))
# Out:
# string1 : The matrix is everywhere
# posiiton of matrix in string 1 4

# %% [markdown]
# ##### example 2

# %%
name=input("eneter your name :")
char=input("enter a letter you need see count from youtr name")
print("the letter {} present in your name {} at postiiton {}".format(char.capitalize(),name.capitalize(),name.find(char)))
# Out:
# eneter your name : kumar
# enter a letter you need see count from youtr name a
# the letter A present in your name Kumar at postiiton 3

# %% [markdown]
# ## index()

# %% [markdown]
# ##### example 1

# %%
email=input("eneter sentence that have a word  world")
posiiton=email.index("world")
print(posiiton)
# Out:
# eneter sentence that have a word  world fake world
# 5

# %% [markdown]
# ##### example 2

# %%
fruits = ["apple", "banana", "cherry", "banana"]
userinput=input("eneter any fruite from this list [apple,banana,cherry, banana]:")
print(fruits.index(userinput.lower()))
# Out:
# eneter any fruite from this list [apple,banana,cherry, banana]: banana
# 1

# %% [markdown]
# ## count()

# %% [markdown]
# ##### example 1

# %%
print(":Paragraph:\n")

paragraph="""python is easy and python is powerful. many students learn python 
because python helps in web development, python helps in automation, and python
helps in data analysis. people like python because python code is simple and python 
code is readable. today python is one of the most popular programming languages and 
many companies use python for different projects."""
print(paragraph,"\n")
userinput=input("eneter the word you want to see that hoe namy time that was used in this paragraph")
print("\nthe word {} usde in this paragraph for {} times".format(userinput,paragraph.count(userinput)))
# Out:
# :Paragraph:
#
# python is easy and python is powerful. many students learn python
# because python helps in web development, python helps in automation, and python
# helps in data analysis. people like python because python code is simple and python
# code is readable. today python is one of the most popular programming languages and
# many companies use python for different projects.
# eneter the word you want to see that hoe namy time that was used in this paragraph python
# the word python usde in this paragraph for 11 times

# %% [markdown]
# ##### example 2

# %%
number=input("enter your phonr number\n")
print ("your phonr number :",number)
print("number 1",number.count("1"))
print("number 2",number.count("2"))
print("number 3",number.count("3"))
print("number 4",number.count("4"))
print("number 5",number.count("5"))
print("number 6",number.count("6"))
print("number 7",number.count("7"))
print("number 8",number.count("8"))
print("number 9",number.count("9"))
print("number 0",number.count("0"))
# Out:
# enter your phonr number
#  9965314383
# your phonr number : 9965314383
# number 1 1
# number 2 0
# number 3 3
# number 4 1
# number 5 1
# number 6 1
# number 7 0
# number 8 1
# number 9 2
# number 0 0

# %% [markdown]
# ## startswith()

# %% [markdown]
# ##### example 1

# %%
name=input("eneter your name")
userid=input("eneter user id start with your name")
if userid.startswith(name)==True:
    print ("valid username and user is")
else:
    print("invalid username and id")
# Out:
# eneter your name raja
# eneter user id start with your name haja@123
# invalid username and id

# %% [markdown]
# ##### example 2

# %%
name=input("eneter your name start with TEAM IT")
if name.startswith("TEAM IT")==True:
    print ("name accepted")
else:
    print("please eneter your name at at begining use TEAM IT")
# Out:
# eneter your name start with TEAM IT TEAM IT raja
# name accepted

# %% [markdown]
# ## endswith()

# %% [markdown]
# ##### example 1

# %%
email=input("eneter you email (include @gmail.com atlast) :\n")
if email.endswith("@gmail.com"):
    print("\nyour email {} accepted successfully".format(email))
else:
    print("\nyour email not accepeted ")
# Out:
# eneter you email (include @gmail.com atlast) :
#  uyagfuqf@gmail.com
# your email uyagfuqf@gmail.com accepted successfully

# %% [markdown]
# ##### example 2

# %%
name=input("eneter your name")
dob=input(" eneter date of birth\n you must born in 2003/n(dd/mm/yyyy) : ")
if dob.endswith("2003" ):
    print("your application accepted")
else:
    print(" your not eligible")
# Out:
# eneter your name raja
#  eneter date of birth
#  you must born in 2003/n(dd/mm/yyyy) :  22/20/2002
#  your not eligible

# %% [markdown]
# ## split()

# %% [markdown]
# ##### example 1

# %%
string1="wlcome to python "
sp=string1.split( )
print(sp)
# Out:
# ['wlcome', 'to', 'python']

# %% [markdown]
# ##### example 2

# %%
fruites = "apple,banana,cherry,orange"

sp = fruites.split(",")
print(sp)
# Out:
# ['apple', 'banana', 'cherry', 'orange']

# %% [markdown]
# ## join()

# %% [markdown]
# ##### example 1

# %%
string1= ['wlcome', 'to', 'python']
join1="-".join(string1)
print(join1)
# Out:
# wlcome-to-python

# %% [markdown]
# ##### example 2

# %%
firstname=input("eneter you fiesrt name")
lastname=input("enter your last name")
list1=[firstname,lastname]
print("welcome ","".join(list1))
# Out:
# eneter you fiesrt name raja
# enter your last name sekar
# welcome  rajasekar

# %% [markdown]
# ## isalpha()

# %% [markdown]
# ##### example 1

# %%
name=input("eneter name (onlu alphebat allowded) :")
if name.isalpha()==True :
    print("wlcome to python")
else:
    print("enter valid name in aplhabet")
# Out:
# eneter name (onlu alphebat allowded) : fdguhyw46
# enter valid name in aplhabet

# %% [markdown]
# ##### example 2

# %%
name="RAMKUMAR"
age="23"
randomsymbools="!@$%^&*"
print(age.isalpha())
print(name.isalpha())
print(randomsymbools.isalpha())
# Out:
# False
# True
# False

# %% [markdown]
# ## isdigit()

# %% [markdown]
# ##### example 1

# %%
number=input("eneter phone number")
if number.isdigit()==True and len(number)==10:
    print("phone number accepted")
else:
    print("enter a integer as phone number not characters or symbools")
# Out:
# eneter phone number 9965314383
# phone number accepted

# %% [markdown]
# ##### example 2

# %%
age="23"

print(age.isdigit())
# Out:
# True

# %% [markdown]
# ## isalnum()

# %% [markdown]
# ##### example 1

# %%
a="ghwuyh547613457"
print(a.isalnum())
# Out:
# True

# %% [markdown]
# ##### example 2

# %%
username=input("eneter username : ")
passward=input("enter passward must combine word and numbers : ")
if passward.isalnum()==True:
    print("\nusername passward successfullycreated")
else:
    print ("try again with strong passward")
# Out:
# eneter username :  raja
# enter passward must combine word and numbers :  sekar123
# username passward successfullycreated

# %% [markdown]
# ## swapcase()

# %%
string1="The Quick Brown Fox Jumps Over the Lazy Dog"
print(string1.swapcase())
# Out:
# tHE qUICK bROWN fOX jUMPS oVER THE lAZY dOG

# %%
userinput=input("eneter a string")
print(userinput.swapcase())
# Out:
# eneter a string Hii Im RAJASEKAR
# hII iM rajasekar
